# %%
from torchvision import datasets, transforms
from torch.utils.data import Dataset, DataLoader
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
import torch
from PIL import Image
import numpy as np

# %%
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
data_path = '../../data/PV_IMAGE/201705/'

# %%
# load dataset
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor()
])
dataset = datasets.ImageFolder(data_path, transform)
data_loader = DataLoader(dataset, batch_size=16, shuffle=True)

# %%
len(data_loader)
# Out:
# 626

# %%
images, labels = iter(data_loader).next()
labels
# Out:
# tensor([ 26,  17,   8,  15,   0,  14,   4,   6,   8,  18,   0,   8,
#           9,  25,  18,   9])

# %%
images.shape
# Out:
# torch.Size([16, 3, 64, 64])

# %%
plt.figure()
imshow(make_grid(images, nrow=4, padding=1))
plt.axis('off')
plt.show()

# %%
def load_batch(istrain):
    batch_size = 4
    if istrain:
        template = '../../data/vae_solar/train/'
    else:
        template = '../../data/vae_solar/test/'
    # l = [str(batch_idx*batch_size + i).zfill(6) for i in range(batch_size)]
    # load dataset
    transform = transforms.Compose([
        transforms.Resize((64, 64)),
        transforms.ToTensor()
    ])
    dataset = datasets.ImageFolder(template, transform)
    data_loader = DataLoader(dataset, batch_size=128, shuffle=True)
    images, labels = iter(data_loader).next()
    return images

# %%
tmp = load_batch(istrain=True)

# %%
tmp.shape
# Out:
# torch.Size([128, 3, 64, 64])
