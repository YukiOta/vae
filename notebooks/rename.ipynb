# %%
import os
from glob import glob

# %%
dataPath = "../../data/"
trainPath = os.path.join(dataPath, "train")

# %%
ls = glob(os.path.join(trainPath, "*.png"))

# %%
ls
# Out:
# ['../../data/train/img000001.png',
#  '../../data/train/img000002.png',
#  '../../data/train/img000003.png',
#  '../../data/train/img000004.png',
#  '../../data/train/img000005.png',
#  '../../data/train/img000006.png',
#  '../../data/train/img000007.png',
#  '../../data/train/img000008.png',
#  '../../data/train/img000009.png',
#  '../../data/train/img000010.png',
#  '../../data/train/img000011.png',
#  '../../data/train/img000012.png',
#  '../../data/train/img000013.png',
#  '../../data/train/img000014.png',
#  '../../data/train/img000015.png',
#  '../../data/train/img000016.png',
#  '../../data/train/img000017.png',
#  '../../data/train/img000018.png',
#  '../../data/train/img000019.png',
#  '../../data/train/img000020.png',
#  '../../data/train/img000021.png',
#  '../../data/train/img000022.png',
#  '../../data/train/img000023.png',
#  '../../data/train/img000024.png',
#  '../../data/train/img000025.png',
#  '../../data/train/img000026.png',
#  '../../data/train/img000027.png',
# ...

# %%
if ls[0].split("/")[-1] == "img000001.png":
    print("unko")
else:
    print("aa")
# Out:
# aa

# %%
for count, filename in enumerate(ls):
    os.rename(ls[count], os.path.join(trainPath, "img{0:06d}".format(count)+os.path.splitext(ls[0])[1]))
